# %% [markdown]
# <a href="https://colab.research.google.com/github/vedprakash226/VisionVerse/blob/main/Filter_Techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-66fb5881-f5bc-47e3-bd02-50755e7f20dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66fb5881-f5bc-47e3-bd02-50755e7f20dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img1 = cv2.imread("1.png")
img2 = cv2.imread("2.jpg")

images = [img1, img2]

# %%
def imageShow(original, filtered):
    plt.figure(figsize=(10,5))

    plt.subplot(1,2,1)
    plt.title("Original Image")
    plt.imshow(cv2.cvtColor(original, cv2.COLOR_BGR2RGB))
    plt.axis("off")

    plt.subplot(1,2,2)
    plt.title("Filtered Image")
    plt.imshow(cv2.cvtColor(filtered, cv2.COLOR_BGR2RGB))
    plt.axis("off")

    plt.show()

# %% [markdown]
# # **Gaussian Filter**

# %%
for img in images:
    x=img.copy()
    filtered = cv2.GaussianBlur(x, (5,5),0)
    imageShow(img, filtered)

# %% [markdown]
# # **Median Filter**

# %%
for img in images:
    x=img.copy()
    filtered = cv2.medianBlur(x,5)
    imageShow(img, filtered)

# %% [markdown]
# # **Laplacian filter**

# %%
for img in images:
    x=img.copy()
    filtered = cv2.Laplacian(x, cv2.CV_64F)
    filtered = np.uint8(np.absolute(filtered))
    imageShow(img, filtered)

# %% [markdown]
# # **Bilateral filter**

# %%
for img in images:
    x=img.copy()
    filter_img = cv2.bilateralFilter(x,15,80,80)
    imageShow(img, filter_img)

# %% [markdown]
# # **Box Filter**

# %%
for img in images:
    x=img.copy()
    filter_img = cv2.boxFilter(x, 0, (7,7), x, (-1,-1), True, cv2.BORDER_DEFAULT)
    imageShow(img, filter_img)
